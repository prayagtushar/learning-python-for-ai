# %%
pip install torch

# %%
age = torch.tensor(20)
print(age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_700/1125397315.py in <cell line: 0>()
# ----> 1 age = torch.tensor(20)
#       2 print(age) #
#
# NameError: name 'torch' is not defined
